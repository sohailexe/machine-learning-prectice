# %% [markdown]
# # introduction to matploot lib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
x=[1,2,3,4]
y=[11,22,33,44]
plt.plot(x,y)

# %%
fig, ax = plt.subplots()

ax.plot(x, y);

# %%
type(fig)
# Out:
# matplotlib.figure.Figure

# %%
type(ax)
# Out:
# matplotlib.axes._axes.Axes

# %%
 # You can make plots from a dictionary
nut_butter_prices = {"Almond butter": 10,
                     "Peanut butter": 8,
                     "Cashew butter": 12}

x=["a","c","b"]
y=[1,2,3]
fig, ax= plt.subplots()
ax.bar(y,x);

# %%
x= np.random.randn(1000)
x
# Out:
# array([-4.88909522e-01, -2.08331238e-01, -1.45465117e+00,  1.54623175e-01,
#        -2.42329895e-03,  1.60095399e-01, -1.16048213e+00,  1.70660819e+00,
#        -9.97662113e-01, -1.49600907e+00, -1.29264035e+00,  4.57145978e-02,
#         6.08375485e-01, -8.85706155e-01,  1.96101414e-01,  5.54861470e-01,
#         1.49817530e-01,  1.10955880e-01, -1.00378058e+00,  1.55955625e-01,
#        -2.66098956e+00, -1.44978738e+00, -2.57559053e+00, -1.30390198e+00,
#        -9.98132579e-02, -1.09033954e+00,  1.30952349e-01, -9.59196601e-01,
#         1.31256525e+00,  5.29869067e-01,  1.70264481e+00, -1.11880252e+00,
#        -1.06146372e+00, -6.57106252e-01, -6.05154622e-01,  3.48024947e-01,
#        -6.37700908e-01, -3.00970517e-01,  2.59316585e+00, -8.63861698e-01,
#         1.18751313e+00, -5.09495222e-01,  4.18366366e-01, -3.33153559e-01,
#         4.17216604e-01,  1.79493811e+00,  1.93812717e+00, -6.51704105e-01,
# ...

# %%
fig,ax = plt.subplots()
ax.hist(x);
