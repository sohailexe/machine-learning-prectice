# %%
import pandas as pd

# %%
df = pd.read_csv("heart-disease.csv")

# %%
df.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# ...

# %%
df.to_csv("Mydata.csv")

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.sum(numeric_only=True)
# Out:
# age         16473.0
# sex           207.0
# cp            293.0
# trestbps    39882.0
# chol        74618.0
# fbs            45.0
# restecg       160.0
# thalach     45343.0
# exang          99.0
# oldpeak       315.0
# slope         424.0
# ca            221.0
# thal          701.0
# target        165.0
# dtype: float64

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.age
# Out:
# 0      63
# 1      37
# 2      41
# 3      56
# 4      57
#        ..
# 298    57
# 299    45
# 300    68
# 301    57
# 302    57
# Name: age, Length: 303, dtype: int64

# %%
df.age[1]
# Out:
# 37

# %%
myColums= df.columns

# %%
myColums
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=303, step=1)

# %%
len(df)
# Out:
# 303

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.head(n=10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# ...

# %%
df.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %%
df.tail(5)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %%
df.loc[301]
# Out:
# age          57.0
# sex           1.0
# cp            0.0
# trestbps    130.0
# chol        131.0
# fbs           0.0
# restecg       1.0
# thalach     115.0
# exang         1.0
# oldpeak       1.2
# slope         1.0
# ca            1.0
# thal          3.0
# target        0.0
# Name: 301, dtype: float64

# %%
df.loc[[301,302]]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 301      1   1     3       0
# 302      1   1     2       0

# %%
df.loc[[301,302],["age","thal"]]
# Out:
#      age  thal
# 301   57     3
# 302   57     2

# %%
df.loc[300:302]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %%
df.loc[300:302 , 'sex':'fbs']
# Out:
#      sex  cp  trestbps  chol  fbs
# 300    1   0       144   193    1
# 301    1   0       130   131    0
# 302    0   1       130   236    0

# %%
df.loc[df.age > 57]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 13    64    1   3       110   211    0        0      144      1      1.8
# 14    58    0   3       150   283    1        0      162      0      1.0
# 16    58    0   2       120   340    0        1      172      0      0.0
# 17    66    0   3       150   226    0        1      114      0      2.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 293   67    1   2       152   212    0        0      150      0      0.8
# 295   63    1   0       140   187    0        0      144      1      4.0
# 296   63    0   0       124   197    0        1      136      1      0.0
# 297   59    1   0       164   176    1        0       90      0      1.0
# 300   68    1   0       144   193    1        1      141      0      3.4
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 13       1   0     2       1
# ...

# %%
df.loc[df.cp <=2 ]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 1        0   0     2       1
# 2        2   0     2       1
# ...

# %%
import numpy as np

# %%
data = {
    'A': np.random.rand(10),
    'B': np.random.rand(10),
    'C': np.random.rand(10)
}

# %%
dataframe= pd.DataFrame(data)

# %%
dataframe
# Out:
#           A         B         C
# 0  0.620874  0.546133  0.467513
# 1  0.981854  0.809616  0.106397
# 2  0.362005  0.193671  0.812246
# 3  0.385035  0.033170  0.754420
# 4  0.764745  0.339721  0.939131
# 5  0.312995  0.600062  0.797695
# 6  0.399984  0.412446  0.863304
# 7  0.425207  0.225000  0.836292
# 8  0.174954  0.482816  0.751774
# 9  0.087440  0.034242  0.489654

# %%
dataframe.plot()
# Out:
# <Axes: >

# %%
len(dataframe)
# Out:
# 10

# %%
df.plot()
# Out:
# <Axes: >

# %%
max(df.chol)
# Out:
# 564

# %%
df.plot(kind='bar')
# Out:
# <Axes: >

# %%
dataframe.plot(kind='bar')
# Out:
# <Axes: >

# %%
dataframe.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
dataframe.plot(kind='scatter', x='A', y='B')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df.plot(kind='box')
# Out:
# <Axes: >

# %%
dataframe.plot(kind='area')
# Out:
# <Axes: >

# %%
dataframe['A'].plot(kind='pie')
# Out:
# <Axes: ylabel='A'>

# %%
dataframe.plot(color=['red', 'green', 'blue'])
# Out:
# <Axes: >

# %%
#.loc and iloc

# %%
animals = pd.Series(["cat","dog","birds","pandas", "snake"], 
                   index=[0,3,9,8,3])

# %%
animals.loc[3]
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
animals.iloc[3]
# Out:
# 'pandas'

# %%
car_data = pd.read_csv("car-sales.csv")

# %%
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
pd.crosstab(car_data["Make"], car_data["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_data["Price"] = car_data["Price"].astype(str).str.replace(r'[ \$\,\.]', '', regex=True).astype(int)

# %%
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_data["Price"].plot()
# Out:
# <Axes: >

# %%
car_data["Make"] = car_data['Make'].str.lower();

# %%
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   400000
# 1   honda    Red          87899      4   500000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 4  nissan  White         213095      4   350000
# 5  toyota  Green          99213      4   450000
# 6   honda   Blue          45698      4   750000
# 7   honda   Blue          54738      4   700000
# 8  toyota  White          60000      4   625000
# 9  nissan  White          31600      4   970000

# %%
car_data['Doors'] = car_data["Doors"]*2

# %%
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      8   400000
# 1   honda    Red          87899      8   500000
# 2  toyota   Blue          32549      6   700000
# 3     bmw  Black          11179     10  2200000
# 4  nissan  White         213095      8   350000
# 5  toyota  Green          99213      8   450000
# 6   honda   Blue          45698      8   750000
# 7   honda   Blue          54738      8   700000
# 8  toyota  White          60000      8   625000
# 9  nissan  White          31600      8   970000

# %%
car_md= pd.read_csv("car-sales-missing-data.csv")

# %%
car_md
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_md["Odometer"].fillna(  car_md["Odometer"].mean()  )
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
car_md["Odometer"].fillna(  car_md["Odometer"].mean()  ,inplace=True)
# Out:
# C:\Users\divso\AppData\Local\Temp\ipykernel_12568\1168053121.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car_md["Odometer"].fillna(  car_md["Odometer"].mean()  ,inplace=True)

# %%
car_md
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_md.fillna({"Doors": car_md["Doors"].mode()[0]}, inplace=True)

# %%
car_md
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    4.0      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_md.dropna(inplace=True)

# %%
seat_col = pd.Series([5,5,5,5,5])

# %%
seat_col
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# 4    5
# dtype: int64

# %%
car_md["Seats"] = seat_col

# %%
car_md
# Out:
#      Make Colour       Odometer  Doors    Price  Seats
# 0  Toyota  White  150043.000000    4.0   $4,000    5.0
# 1   Honda    Red   87899.000000    4.0   $5,000    5.0
# 2  Toyota   Blue   92302.666667    3.0   $7,000    5.0
# 3     BMW  Black   11179.000000    5.0  $22,000    5.0
# 4  Nissan  White  213095.000000    4.0   $3,500    5.0
# 5  Toyota  Green   92302.666667    4.0   $4,500    NaN

# %%
car_md
# Out:
#      Make Colour       Odometer  Doors    Price  Seats
# 0  Toyota  White  150043.000000    4.0   $4,000    5.0
# 1   Honda    Red   87899.000000    4.0   $5,000    5.0
# 2  Toyota   Blue   92302.666667    3.0   $7,000    5.0
# 3     BMW  Black   11179.000000    5.0  $22,000    5.0
# 4  Nissan  White  213095.000000    4.0   $3,500    5.0
# 5  Toyota  Green   92302.666667    4.0   $4,500    5.0

# %%
car_md.drop("Doors", axis=1, inplace=True)

# %%
car_md
# Out:
#      Make Colour       Odometer    Price  Seats
# 0  Toyota  White  150043.000000   $4,000    5.0
# 1   Honda    Red   87899.000000   $5,000    5.0
# 2  Toyota   Blue   92302.666667   $7,000    5.0
# 3     BMW  Black   11179.000000  $22,000    5.0
# 4  Nissan  White  213095.000000   $3,500    5.0
# 5  Toyota  Green   92302.666667   $4,500    5.0

# %%
car_mdr=car_md.sample(frac=1)

# %%
car_mdr
# Out:
#      Make Colour       Odometer    Price  Seats
# 3     BMW  Black   11179.000000  $22,000    5.0
# 0  Toyota  White  150043.000000   $4,000    5.0
# 5  Toyota  Green   92302.666667   $4,500    5.0
# 4  Nissan  White  213095.000000   $3,500    5.0
# 1   Honda    Red   87899.000000   $5,000    5.0
# 2  Toyota   Blue   92302.666667   $7,000    5.0

# %%
car_mdr.sample(frac=.5)
# Out:
#      Make Colour  Odometer   Price  Seats
# 4  Nissan  White  213095.0  $3,500    5.0
# 0  Toyota  White  150043.0  $4,000    5.0
# 1   Honda    Red   87899.0  $5,000    5.0

# %%
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      8   400000
# 1   honda    Red          87899      8   500000
# 2  toyota   Blue          32549      6   700000
# 3     bmw  Black          11179     10  2200000
# 4  nissan  White         213095      8   350000
# 5  toyota  Green          99213      8   450000
# 6   honda   Blue          45698      8   750000
# 7   honda   Blue          54738      8   700000
# 8  toyota  White          60000      8   625000
# 9  nissan  White          31600      8   970000

# %%
car_data_shuffle = car_data.sample(frac=1)

# %%
car_data_shuffle
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 5  toyota  Green          99213      8   450000
# 6   honda   Blue          45698      8   750000
# 7   honda   Blue          54738      8   700000
# 3     bmw  Black          11179     10  2200000
# 1   honda    Red          87899      8   500000
# 8  toyota  White          60000      8   625000
# 4  nissan  White         213095      8   350000
# 9  nissan  White          31600      8   970000
# 2  toyota   Blue          32549      6   700000
# 0  toyota  White         150043      8   400000

# %%
car_data_shuffle.reset_index()
# Out:
#    index    Make Colour  Odometer (KM)  Doors    Price
# 0      5  toyota  Green          99213      8   450000
# 1      6   honda   Blue          45698      8   750000
# 2      7   honda   Blue          54738      8   700000
# 3      3     bmw  Black          11179     10  2200000
# 4      1   honda    Red          87899      8   500000
# 5      8  toyota  White          60000      8   625000
# 6      4  nissan  White         213095      8   350000
# 7      9  nissan  White          31600      8   970000
# 8      2  toyota   Blue          32549      6   700000
# 9      0  toyota  White         150043      8   400000

# %%
car_data = pd.read_csv("car-sales.csv")

# %%
car_ds= car_data.sample(frac=1)

# %%
car_ds
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 4  Nissan  White         213095      4   $3,500.00
# 8  Toyota  White          60000      4   $6,250.00
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 5  Toyota  Green          99213      4   $4,500.00
# 9  Nissan  White          31600      4   $9,700.00
# 3     BMW  Black          11179      5  $22,000.00
# 7   Honda   Blue          54738      4   $7,000.00
# 6   Honda   Blue          45698      4   $7,500.00
# 2  Toyota   Blue          32549      3   $7,000.00

# %%
car_ds.reset_index()
# Out:
#    index    Make Colour  Odometer (KM)  Doors       Price
# 0      4  Nissan  White         213095      4   $3,500.00
# 1      8  Toyota  White          60000      4   $6,250.00
# 2      0  Toyota  White         150043      4   $4,000.00
# 3      1   Honda    Red          87899      4   $5,000.00
# 4      5  Toyota  Green          99213      4   $4,500.00
# 5      9  Nissan  White          31600      4   $9,700.00
# 6      3     BMW  Black          11179      5  $22,000.00
# 7      7   Honda   Blue          54738      4   $7,000.00
# 8      6   Honda   Blue          45698      4   $7,500.00
# 9      2  Toyota   Blue          32549      3   $7,000.00

# %%
car_ds.drop("index", axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 car_ds.drop("index", axis=1, inplace=True)
#
# File ~\OneDrive\Desktop\Machine\first_ml_project\env\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
car_ds["del"]=range(10)

# %%
car_ds
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  del
# 4  Nissan  White         213095      4   $3,500.00    0
# 8  Toyota  White          60000      4   $6,250.00    1
# 0  Toyota  White         150043      4   $4,000.00    2
# 1   Honda    Red          87899      4   $5,000.00    3
# 5  Toyota  Green          99213      4   $4,500.00    4
# 9  Nissan  White          31600      4   $9,700.00    5
# 3     BMW  Black          11179      5  $22,000.00    6
# 7   Honda   Blue          54738      4   $7,000.00    7
# 6   Honda   Blue          45698      4   $7,500.00    8
# 2  Toyota   Blue          32549      3   $7,000.00    9

# %%
car_ds.drop("del", axis=1, inplace=True)

# %%
car_ds
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 4  Nissan  White         213095      4   $3,500.00
# 8  Toyota  White          60000      4   $6,250.00
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 5  Toyota  Green          99213      4   $4,500.00
# 9  Nissan  White          31600      4   $9,700.00
# 3     BMW  Black          11179      5  $22,000.00
# 7   Honda   Blue          54738      4   $7,000.00
# 6   Honda   Blue          45698      4   $7,500.00
# 2  Toyota   Blue          32549      3   $7,000.00

# %%
car_ds.drop("index", axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 car_ds.drop("index", axis=1, inplace=True)
#
# File ~\OneDrive\Desktop\Machine\first_ml_project\env\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
car_ds.reset_index(drop=True, inplace=True)

# %%
car_ds
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Nissan  White         213095      4   $3,500.00
# 1  Toyota  White          60000      4   $6,250.00
# 2  Toyota  White         150043      4   $4,000.00
# 3   Honda    Red          87899      4   $5,000.00
# 4  Toyota  Green          99213      4   $4,500.00
# 5  Nissan  White          31600      4   $9,700.00
# 6     BMW  Black          11179      5  $22,000.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8   Honda   Blue          45698      4   $7,500.00
# 9  Toyota   Blue          32549      3   $7,000.00
